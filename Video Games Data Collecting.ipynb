# %% [markdown]
# # **Video Games Data Collecting**
# --------------------------------------------------------------------------
# 1. Scraping all games data from https://www.bookstores.com/ including name , price , platform , weight , cover_link and category of game and saving this data in csv file (Video Games.csv) .
#
# 2. I used many libraries in this project as BeautifulSoup for collecting data and selenium for automate switching between web pages
#
# 3. In website we've old video games and categories for video games as Xbox 360 , Play Station 3 , Sony PSP and PC
#
# ### Steps of collecting this data :
#      1.   Collecting Games Data for any category that've only one web page
#      2.   Collecting Games Data for any category that've many web page
#      3.   Collecting Games Data for all Categories in the website
#      4.   Saving this Data in csv file (Video Games.csv)
# ### Columns in csv file :
#     1. Name : Video Game Name
#     2. Studio : Studio that've designed the game
#     3. UPC : Unit Product Code for game
#     4. Price :  Video Game Price
#     5. Category :  Video Game Category (According to website)
#     6. ESRB :  Who can play this game from consumer of video games ?    (According to  ESRB Organization)
#     7. Platform : Platform that run the game
#     8. Released_on : Date of Releasing of Game
#     9. Dimensions : Width x Height of game
#     10. Weight : Video Game Weight in lbs
#     11. Cover_image : Cover Image Link of the game (Image in website)

# %%
import requests
import csv
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %%
Path = 'E:\Aslm\Driver\chromedriver.exe'
browser = webdriver.Chrome(Path)

# %%
response = requests.get('https://www.bookstores.com//search/search-results.aspx?format=mac&pt=3')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
games_categories_list = soup.find_all('ul' , {'class' : 'categories-list'})[-1]
games_categories_list
# Out:
# <ul class="categories-list">
# <li><a href="/search/search-results.aspx?format=playStation&amp;pt=3">PlayStation 3</a></li>
# <li><a href="/search/search-results.aspx?format=xbox&amp;pt=3">Xbox 360</a></li>
# <li><a href="/search/search-results.aspx?format=wii&amp;pt=3">Wii</a></li>
# <li><a href="/search/search-results.aspx?format=psp&amp;pt=3">Sony PSP</a></li>
# <li><a href="/search/search-results.aspx?format=3ds&amp;pt=3">Nintendo 3DS</a></li>
# <li><a href="/search/search-results.aspx?format=DS&amp;pt=3">Nintendo DS</a></li>
# <li><a href="/search/search-results.aspx?format=windows&amp;pt=3">PC</a></li>
# <li><a href="/search/search-results.aspx?format=mac&amp;pt=3">Mac</a></li>
# <li><a href="/search/search-results.aspx?format=all&amp;pt=3">Browse games</a></li>
# </ul>

# %%
games_categories_list_tag = games_categories_list.find_all('li')[:-1]
games_categories_list_tag
# Out:
# [<li><a href="/search/search-results.aspx?format=playStation&amp;pt=3">PlayStation 3</a></li>,
#  <li><a href="/search/search-results.aspx?format=xbox&amp;pt=3">Xbox 360</a></li>,
#  <li><a href="/search/search-results.aspx?format=wii&amp;pt=3">Wii</a></li>,
#  <li><a href="/search/search-results.aspx?format=psp&amp;pt=3">Sony PSP</a></li>,
#  <li><a href="/search/search-results.aspx?format=3ds&amp;pt=3">Nintendo 3DS</a></li>,
#  <li><a href="/search/search-results.aspx?format=DS&amp;pt=3">Nintendo DS</a></li>,
#  <li><a href="/search/search-results.aspx?format=windows&amp;pt=3">PC</a></li>,
#  <li><a href="/search/search-results.aspx?format=mac&amp;pt=3">Mac</a></li>]

# %%
category_name_list = []
category_link_list = []
for game_category_tag in games_categories_list_tag :
    category_name = game_category_tag.get_text()
    category_name_list.append(category_name)
    category_link = 'https://www.bookstores.com' + game_category_tag.find('a').get('href')
    category_link_list.append(category_link)
    print(f'category name : {category_name}')
    print(f'{category_link}')
    print('---'*40)
# Out:
# category name : PlayStation 3
# https://www.bookstores.com/search/search-results.aspx?format=playStation&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : Xbox 360
# https://www.bookstores.com/search/search-results.aspx?format=xbox&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : Wii
# https://www.bookstores.com/search/search-results.aspx?format=wii&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : Sony PSP
# https://www.bookstores.com/search/search-results.aspx?format=psp&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : Nintendo 3DS
# https://www.bookstores.com/search/search-results.aspx?format=3ds&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : Nintendo DS
# https://www.bookstores.com/search/search-results.aspx?format=DS&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : PC
# https://www.bookstores.com/search/search-results.aspx?format=windows&pt=3
# ------------------------------------------------------------------------------------------------------------------------
# category name : Mac
# https://www.bookstores.com/search/search-results.aspx?format=mac&pt=3
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Step One
# 1. Scraping Data from video game category (mac) that have only one web page
# 2. Saving Data in csv file (mac.csv)

# %%
response = requests.get('https://www.bookstores.com/search/search-results.aspx?format=mac&pt=3')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
item_tag = soup.find('div',{'class':'itemListingDiv'})
item_tag
# Out:
# <div class="itemListingDiv" itemtype="https://schema.org/Product" onclick="window.location.assign('/browse/games/0014633098808')">
# <div id="imageAndMobileType">
# <span class="searchProdImg">
# <img src="https://secure.coverart.bookstores.com/medium/647/3-56647.jpg"/>
# </span>
# </div>
# <div class="productListingInfo">
# <span class="searchTitleSpan blue truncate"> <a href="/browse/games/0014633098808" itemprop="name">Portal 2 - PC</a></span>
# <span class="searchAuthorSpan mobile Truncate">
# <a href="/search/search-results.aspx?search=Valve">
#                                     Valve
#                                 </a>
# </span>
# <div class="mainListingInfo">
# <div class="searchListingInfo">
# <span class="searchEditionSpan">
#                                     Mac OS X
#                                     <br/>
# </span><span class="searchISBNSpan">
#                                      / 0014633098808
#                                     <br/>
# </span><span class="serchListPriceSpan">
# <span class="listPriceLabel">List Price: </span>
# <span class="listPriceAmount">$29.99</span>
# <br/>
# </span>
# <div class="stockAndType" style="display:none">
# <span class="stockIcon">
# <img src="/images/browse/out-of-stock.jpg" title="This item is out of stock">
# </img></span><span class="typeIcon">
# <img src="/images/games_icon.png"/>
# </span>
# </div>
# </div>
# <div class="searchPriceInfo">
# <p>
# <span class="searchOurPrice" id="spnOurPrice" style="display:none">Buy it from:
#                                         <span itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
# <a href="/browse/games/0014633098808" itemprop="price">$79,228,162,514,264,337,593,543,950,335.00</a>
# </span>
# </span>
# </p>
# <p>
# <span class="searchRentPrice" id="spnRentPrice" style="display:none">Rent it for:
#                                         <a href="/browse/games/0014633098808?r=1"></a>
# </span>
# </p>
# <p>
# <span id="spnSellIt" style="display:none">
# <strong>Have one to sell? </strong><a class="blue" href="/sell/search-results.aspx?pt=3&amp;st=1&amp;criteria=0014633098808" title="Get a quote!">We'll buy it!</a>
# </span>
# </p>
# </div>
# </div>
# </div>
# </div>

# %%
item_name = item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).get_text()
item_name
# Out:
# ' Portal 2 - PC'

# %%
studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
studio
# Out:
# 'Valve'

# %%
run_on = item_tag.find('span',{'class':'searchEditionSpan'}).get_text().strip()
run_on
# Out:
# 'Mac OS X'

# %%
upc = item_tag.find('span',{'class':'searchISBNSpan'}).get_text().strip().split('/')[1].strip()
upc
# Out:
# '0014633098808'

# %%
price = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1])
price
# Out:
# 29.99

# %%
item_link =  item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).find('a').get('href')
item_link = 'https://www.bookstores.com' + item_link
print(item_link)
# Out:
# https://www.bookstores.com/browse/games/0014633098808

# %%
response = requests.get(item_link)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
item_img_link = soup.find('img', {'id':'mainContentRegion_imgProductImage'}).get('src')
print(item_img_link)
# Out:
# https://secure.coverart.bookstores.com/large/647/3-56647.jpg

# %%
esrb = soup.find('span', {'id':'mainContentRegion_lblAuthorFormatESRB'}).get_text()
esrb
# Out:
# 'Everyone 10+'

# %%
platform = soup.find('span', {'id':'mainContentRegion_lblEditionRatingPlatform'}).get_text().split(':')[1].strip()
platform
# Out:
# 'Mac OS X'

# %%
released_on = soup.find('span', {'id':'mainContentRegion_lblPagesActorsReleaseDate'}).get_text().split(':')[1].strip()
released_on
# Out:
# '4/19/2011'

# %%
dimensions = soup.find('span', {'id':'mainContentRegion_lblDimensions'}).get_text().split(':')[1].strip()
dimensions
# Out:
# '5.3000 x 0.6000'

# %%
weight = soup.find('span', {'id':'mainContentRegion_lblWeight'}).get_text().split(':')[1].strip()
weight
# Out:
# '0.1000 lbs.'

# %%
response = requests.get('https://www.bookstores.com/search/search-results.aspx?format=mac&pt=3')
soup = BeautifulSoup(response.text, 'html.parser')
items_tag = soup.find_all('div',{'class':'itemListingDiv'})
for item_tag in items_tag : 
    item_name = item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).get_text()
    try :
        studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
        if studio == '' :
            studio = 'Unknown'  
    except : 
           studio = 'Unknown'    
    upc = item_tag.find('span',{'class':'searchISBNSpan'}).get_text().strip().split('/')[1].strip()
    price = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1])
    item_link =  item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).find('a').get('href')
    item_link = 'https://www.bookstores.com' + item_link    
    response = requests.get(item_link)
    soup_item = BeautifulSoup(response.text, 'html.parser')
    item_img_link = soup_item.find('img', {'id':'mainContentRegion_imgProductImage'}).get('src')
    try :
        esrb = soup_item.find('span', {'id':'mainContentRegion_lblAuthorFormatESRB'}).get_text()
    except :
        esrb='Unknown'
    platform = soup_item.find('span', {'id':'mainContentRegion_lblEditionRatingPlatform'}).get_text().split(':')[1].strip()
    released_on = soup_item.find('span', {'id':'mainContentRegion_lblPagesActorsReleaseDate'}).get_text().split(':')[1].strip()    
    try :
        dimensions = soup_item.find('span', {'id':'mainContentRegion_lblDimensions'}).get_text().split(':')[1].strip()
    except :
        dimensions='Unknown'    
    try :
        weight = soup_item.find('span', {'id':'mainContentRegion_lblWeight'}).get_text().split(':')[1].strip()
    except :
        weight='Unknown'  
    print(f'''
           {item_name}  || {studio} || {upc} || {price} || {esrb} || {platform} 
           {released_on} || {dimensions}  || {weight}
           ''')
    print('\t'+item_img_link)
    print('---'*40)
# Out:
#             Portal 2 - PC  || Valve || 0014633098808 || 29.99 || Everyone 10+ || Mac OS X
#            4/19/2011 || 5.3000 x 0.6000  || 0.1000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/647/3-56647.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             The Sims 3 - PC  || Electronic Arts || 0014633153903 || 19.99 || Teen || Mac OS X
#            6/2/2009 || Unknown  || 0.4267 lbs.
#
# 	https://secure.coverart.bookstores.com/large/631/3-7631.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Dragon Age 2 - PC  || Electronic Arts || 0014633194999 || 19.99 || Mature || Mac OS X
#            3/8/2011 || Unknown  || 0.2500 lbs.
#
# 	https://secure.coverart.bookstores.com/large/659/3-10659.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Diablo  || Blizzard || 0020626711883 || 39.99 || Mature || Mac
#            1/17/2044 || 4.9000 x 0.4000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/409/3-11409.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             IGT Slots: Wolf Run - Mac  || Masque Publishing || 0098252104225 || 19.99 || Teen || Mac OS X Intel
#            9/1/2010 || Unknown  || 0.2500 lbs.
#
# 	https://secure.coverart.bookstores.com/large/508/3-19508.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             The Sims 2 Pets Expansion Pack - Mac  || Aspyr Media || 0618870115009 || 34.99 || Teen || Mac
#            11/1/2006 || 5.3000 x 1.1000  || 0.3000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/756/3-2756.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Call of Duty 4: Modern Warfare - Mac  || Aspyr Media || 0618870117607 || 39.99 || Mature || Mac OS X Intel
#            5/8/2011 || 5.3000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/772/3-2772.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             The Sims 2 Bon Voyage - Mac  || Aspyr Media || 0618870117805 || 34.99 || Teen || Mac
#            12/10/2007 || Unknown  || 0.3300 lbs.
#
# 	https://secure.coverart.bookstores.com/large/548/3-19548.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Nancy Drew: Trail of the Twister - Mac  || Her Interactive || 0767861600779 || 19.99 || Everyone || Mac OS X Intel
#            6/29/2010 || 5.4000 x 0.6000  || 0.2500 lbs.
#
# 	https://secure.coverart.bookstores.com/large/691/3-10691.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Nancy Drew: Shadow at the Water's Edge - PC/Mac  || Her Interactive || 0767861600793 || 19.99 || Everyone 10+ || Mac OS X Intel
#            10/19/2010 || Unknown  || 0.3000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/657/3-10657.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Age Of Empires III - Mac  || Microsoft || 0828068103248 || 49.99 || Teen || Mac OS X Intel
#            11/21/2006 || 5.3500 x 1.4200  || 0.5300 lbs.
#
# 	https://secure.coverart.bookstores.com/large/755/3-2755.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#             Age of Empires III: The War Chiefs Expansion Pack  || Destineer || 0828068103309 || 10.0 || Teen || Mac
#            6/12/2007 || 5.3000 x 0.9000  || 0.3500 lbs.
#
# 	https://secure.coverart.bookstores.com/large/526/3-19526.jpg
# ------------------------------------------------------------------------------------------------------------------------

# %%
start_time = time.time()
file_name = 'data\Mac.csv'
response = requests.get('https://www.bookstores.com/search/search-results.aspx?format=mac&pt=3')
soup = BeautifulSoup(response.text, 'html.parser')
items_tag = soup.find_all('div',{'class':'itemListingDiv'})    
with open(file_name, mode='w', encoding='utf-8') as csv_file:
    fieldnames = ['Name', 'Studio'  , 'UPC', 'Price' , 'ESRB' ,
                 'Platform' , 'Released_on' , 'Dimensions' , 'Weight' ,'Cover_image']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for item_tag in items_tag : 
        item_name = item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).get_text()
        try :
            studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
            if studio == '' :
                 studio = 'Unknown'     
        except : 
               studio = 'Unknown'        
        studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
        upc = item_tag.find('span',{'class':'searchISBNSpan'}).get_text().strip().split('/')[1].strip()
        try :
            price = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1])
        except :
            price  = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1].split(')')[0])
        item_link =  item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).find('a').get('href')
        item_link = 'https://www.bookstores.com' + item_link    
        response = requests.get(item_link)
        soup_item = BeautifulSoup(response.text, 'html.parser')
        item_img_link = soup_item.find('img', {'id':'mainContentRegion_imgProductImage'}).get('src')
        try :
            esrb = soup_item.find('span', {'id':'mainContentRegion_lblAuthorFormatESRB'}).get_text()
        except :
            esrb='Unknown'
        platform = soup_item.find('span', {'id':'mainContentRegion_lblEditionRatingPlatform'}).get_text().split(':')[1].strip()
        released_on = soup_item.find('span', {'id':'mainContentRegion_lblPagesActorsReleaseDate'}).get_text().split(':')[1].strip()    
        try :
            dimensions = soup_item.find('span', {'id':'mainContentRegion_lblDimensions'}).get_text().split(':')[1].strip()
        except :
            dimensions='Unknown'    
        try :
            weight = soup_item.find('span', {'id':'mainContentRegion_lblWeight'}).get_text().split(':')[1].strip()
        except :
            weight='Unknown'  
        writer.writerow({'Name': item_name, 'Studio': studio ,  'UPC': upc , 'Price' :price
                         , 'ESRB' : esrb , 'Platform' : platform , 'Released_on' : released_on
                        , 'Dimensions' : dimensions , 'Weight' : weight , 'Cover_image' : item_img_link})
        end_time = time.time()
saving_time = end_time - start_time        
print('Saving Take :' + str(saving_time))
# Out:
# Saving Take :17.944026231765747

# %%
df = pd.read_csv(file_name)
df
# Out:
#                                                  Name             Studio  \
# 0                                       Portal 2 - PC              Valve
# 1                                     The Sims 3 - PC    Electronic Arts
# 2                                   Dragon Age 2 - PC    Electronic Arts
# 3                                              Diablo           Blizzard
# 4                           IGT Slots: Wolf Run - Mac  Masque Publishing
# 5                The Sims 2 Pets Expansion Pack - Mac        Aspyr Media
# 6                Call of Duty 4: Modern Warfare - Mac        Aspyr Media
# 7                         The Sims 2 Bon Voyage - Mac        Aspyr Media
# 8              Nancy Drew: Trail of the Twister - Mac    Her Interactive
# 9     Nancy Drew: Shadow at the Water's Edge - PC/Mac    Her Interactive
# 10                           Age Of Empires III - Mac          Microsoft
# 11   Age of Empires III: The War Chiefs Expansion ...          Destineer
#
#              UPC  Price          ESRB        Platform Released_on  \
# 0    14633098808  29.99  Everyone 10+        Mac OS X   4/19/2011
# 1    14633153903  19.99          Teen        Mac OS X    6/2/2009
# 2    14633194999  19.99        Mature        Mac OS X    3/8/2011
# 3    20626711883  39.99        Mature             Mac   1/17/2044
# 4    98252104225  19.99          Teen  Mac OS X Intel    9/1/2010
# 5   618870115009  34.99          Teen             Mac   11/1/2006
# 6   618870117607  39.99        Mature  Mac OS X Intel    5/8/2011
# 7   618870117805  34.99          Teen             Mac  12/10/2007
# 8   767861600779  19.99      Everyone  Mac OS X Intel   6/29/2010
# 9   767861600793  19.99  Everyone 10+  Mac OS X Intel  10/19/2010
# 10  828068103248  49.99          Teen  Mac OS X Intel  11/21/2006
# 11  828068103309  10.00          Teen             Mac   6/12/2007
#
#          Dimensions       Weight  \
# 0   5.3000 x 0.6000  0.1000 lbs.
# 1           Unknown  0.4267 lbs.
# 2           Unknown  0.2500 lbs.
# 3   4.9000 x 0.4000  0.2000 lbs.
# 4           Unknown  0.2500 lbs.
# 5   5.3000 x 1.1000  0.3000 lbs.
# 6   5.3000 x 0.6000  0.2000 lbs.
# 7           Unknown  0.3300 lbs.
# 8   5.4000 x 0.6000  0.2500 lbs.
# 9           Unknown  0.3000 lbs.
# 10  5.3500 x 1.4200  0.5300 lbs.
# 11  5.3000 x 0.9000  0.3500 lbs.
#
#                                           Cover_image
# 0   https://secure.coverart.bookstores.com/large/6...
# 1   https://secure.coverart.bookstores.com/large/6...
# 2   https://secure.coverart.bookstores.com/large/6...
# 3   https://secure.coverart.bookstores.com/large/4...
# 4   https://secure.coverart.bookstores.com/large/5...
# 5   https://secure.coverart.bookstores.com/large/7...
# 6   https://secure.coverart.bookstores.com/large/7...
# 7   https://secure.coverart.bookstores.com/large/5...
# 8   https://secure.coverart.bookstores.com/large/6...
# 9   https://secure.coverart.bookstores.com/large/6...
# 10  https://secure.coverart.bookstores.com/large/7...
# 11  https://secure.coverart.bookstores.com/large/5...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         12 non-null     object
#  1   Studio       12 non-null     object
#  2   UPC          12 non-null     int64
#  3   Price        12 non-null     float64
#  4   ESRB         12 non-null     object
#  5   Platform     12 non-null     object
#  6   Released_on  12 non-null     object
#  7   Dimensions   12 non-null     object
#  8   Weight       12 non-null     object
#  9   Cover_image  12 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.1+ KB

# %% [markdown]
# ## Step Two
# 1. Scraping Data from video game category (sony psp) that have more than one web page
# 2. Using Selenum to automate switching from one page to anthor
# 3. Saving Data in csv file (sony psp.csv)

# %%
sony_psp_link = 'https://www.bookstores.com/search/search-results.aspx?format=psp&pt=3'
response = requests.get(sony_psp_link)

# %%
def print_collected_data(response) :
    try :
        soup = BeautifulSoup(response.text, 'html.parser')
    except :
        soup = BeautifulSoup(response, 'html.parser')
    items_tag = soup.find_all('div',{'class':'itemListingDiv'})
    for item_tag in items_tag : 
        item_name = item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).get_text()
        try :
            studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
            if studio == '' :
                 studio = 'Unknown'     
        except : 
            studio = 'Unknown'     
        upc = item_tag.find('span',{'class':'searchISBNSpan'}).get_text().strip().split('/')[1].strip()
        try :
            price = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1])
        except :
            price  = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1].split(')')[0])
        item_link =  item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).find('a').get('href')
        item_link = 'https://www.bookstores.com' + item_link    
        response = requests.get(item_link)
        soup_item = BeautifulSoup(response.text, 'html.parser')
        item_img_link = soup_item.find('img', {'id':'mainContentRegion_imgProductImage'}).get('src')
        try :
            esrb = soup_item.find('span', {'id':'mainContentRegion_lblAuthorFormatESRB'}).get_text()
        except :
            esrb='Unknown'
        platform = soup_item.find('span', {'id':'mainContentRegion_lblEditionRatingPlatform'}).get_text().split(':')[1].strip()
        released_on = soup_item.find('span', {'id':'mainContentRegion_lblPagesActorsReleaseDate'}).get_text().split(':')[1].strip()    
        try :
            dimensions = soup_item.find('span', {'id':'mainContentRegion_lblDimensions'}).get_text().split(':')[1].strip()
        except :
            dimensions='Unknown'    
        try :
            weight = soup_item.find('span', {'id':'mainContentRegion_lblWeight'}).get_text().split(':')[1].strip()
        except :
            weight='Unknown'  
        print(f'''
               {item_name}  || {studio}  || {upc} || {price} || {esrb} || {platform} 
               {released_on} || {dimensions}  || {weight}
               ''')
        print('\t'+item_img_link)
        print('---'*40)

# %%
print_collected_data(response)
# Out:
#                 Wall.E (PSP) by THQ  || THQ  || 4005209106320 || 55.13 || Rating Pending || Sony PSP
#                8/18/2042 || 4.0900 x 0.5500  || 0.2200 lbs.
#
# 	https://secure.coverart.bookstores.com/large/612/3-64612.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 NASCAR 07 (PSP)  || Electronic Arts  || 5030930051440 || 19.99 || Unknown || Sony PSP
#                10/5/2006 || 4.0900 x 0.6300  || 0.1800 lbs.
#
# 	https://secure.coverart.bookstores.com/large/030/3-67030.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Battle Over The Pacific (PSP)  || Midas  || 5036675013415 || 14.99 || Unknown || Sony PSP
#                3/21/2008 || 4.0900 x 0.4700  || 0.1800 lbs.
#
# 	https://secure.coverart.bookstores.com/large/057/3-66057.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Prince of Persia: Revelations - Sony PSP  || "Sega of America, Inc."  || 0008888331988 || 19.99 || Mature || Sony PSP
#                9/8/2006 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/550/3-5550.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Assassin's Creed: Bloodlines - Sony PSP  || UBI Soft  || 0008888335733 || 19.99 || Mature || Sony PSP
#                11/17/2009 || 4.1000 x 0.6000  || 0.1000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/043/3-6043.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Michael Jackson The Experience - Sony PSP  || UBI Soft  || 0008888336297 || 1.0 || Everyone 10+ || Sony PSP
#                11/23/2010 || Unknown  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/307/3-39307.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Sonic Rivals 2 - Sony PSP  || Sega of America, Inc.  || 0010086660227 || 29.99 || Everyone || Sony PSP
#                11/13/2007 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/902/3-5902.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Tiger Woods PGA Tour 09 - Sony PSP  || Electronic Arts  || 0014633155075 || 19.99 || Everyone || Sony PSP
#                8/26/2008 || 4.0900 x 0.3100  || 0.0400 lbs.
#
# 	https://secure.coverart.bookstores.com/large/959/3-5959.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Need for Speed Most Wanted - Sony PSP  || Electronic Arts  || 0014633169195 || 19.99 || Everyone 10+ || Sony PSP
#                6/22/2010 || 4.1000 x 0.6000  || 0.1500 lbs.
#
# 	https://secure.coverart.bookstores.com/large/671/3-56671.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 NCAA Football 10 - Sony PSP  || Electronic Arts  || 0014633190144 || 19.99 || Everyone || Sony PSP
#                7/14/2009 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/013/3-6013.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Madden NFL 11 - Sony PSP  || Electronic Arts  || 0014633193534 || 19.99 || Everyone || Sony PSP
#                8/10/2010 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/068/3-6068.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Madden NFL 12 - Sony PSP  || Electronic Arts  || 0014633196702 || 19.99 || Everyone || Sony PSP
#                8/30/2011 || 4.1000 x 0.5000  || 0.3000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/499/3-58499.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Dead Or Alive Paradise  || TechnoMarine  || 0018946010670 || 29.99 || Mature || Sony PSP
#                3/15/2010 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/092/3-6092.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 LEGO Indiana Jones 2 The Adventure Continues (Sony PSP) (UK Import)  || Unknown  || 0023272008413 || 1.0 || Rating Pending || Sony PSP
#                1/17/2044 || 4.1000 x 0.6000  || 0.1400 lbs.
#
# 	https://secure.coverart.bookstores.com/large/290/3-81290.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 LEGO Star Wars 3: The Clone Wars (PSP)  || Activision  || 0023272009670 || 29.99 || Everyone || Sony PSP
#                3/25/2011 || 4.1000 x 0.6000  || 0.1600 lbs.
#
# 	https://secure.coverart.bookstores.com/large/959/3-63959.jpg
# ------------------------------------------------------------------------------------------------------------------------

# %%
browser.get(sony_psp_link)

# %%
browser.find_element_by_id('mainContentRegion_leftContentRegion_btnNext').click()

# %%
response = requests.get(sony_psp_link)
browser.get(sony_psp_link)
i = 1
while True :
        print('Page ' + str(i))
        print('--------')
        print('\n')
        print_collected_data(response)
        try :         
            browser.find_element_by_id('mainContentRegion_leftContentRegion_btnNext').click()
            response = browser.page_source
            time.sleep(3)            
            i += 1
            print('\n\n')
            print('\tTo Next Page\n\n')
        except : 
            print('No Data Available')
            break
# Out:
# Page 1
# --------
#
#
#
#                 Wall.E (PSP) by THQ  || THQ  || 4005209106320 || 55.13 || Rating Pending || Sony PSP
#                8/18/2042 || 4.0900 x 0.5500  || 0.2200 lbs.
#
# 	https://secure.coverart.bookstores.com/large/612/3-64612.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 NASCAR 07 (PSP)  || Electronic Arts  || 5030930051440 || 19.99 || Unknown || Sony PSP
#                10/5/2006 || 4.0900 x 0.6300  || 0.1800 lbs.
#
# 	https://secure.coverart.bookstores.com/large/030/3-67030.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Battle Over The Pacific (PSP)  || Midas  || 5036675013415 || 14.99 || Unknown || Sony PSP
#                3/21/2008 || 4.0900 x 0.4700  || 0.1800 lbs.
#
# 	https://secure.coverart.bookstores.com/large/057/3-66057.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Prince of Persia: Revelations - Sony PSP  || "Sega of America, Inc."  || 0008888331988 || 19.99 || Mature || Sony PSP
#                9/8/2006 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/550/3-5550.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Assassin's Creed: Bloodlines - Sony PSP  || UBI Soft  || 0008888335733 || 19.99 || Mature || Sony PSP
#                11/17/2009 || 4.1000 x 0.6000  || 0.1000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/043/3-6043.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Michael Jackson The Experience - Sony PSP  || UBI Soft  || 0008888336297 || 1.0 || Everyone 10+ || Sony PSP
#                11/23/2010 || Unknown  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/307/3-39307.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Sonic Rivals 2 - Sony PSP  || Sega of America, Inc.  || 0010086660227 || 29.99 || Everyone || Sony PSP
#                11/13/2007 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/902/3-5902.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Tiger Woods PGA Tour 09 - Sony PSP  || Electronic Arts  || 0014633155075 || 19.99 || Everyone || Sony PSP
#                8/26/2008 || 4.0900 x 0.3100  || 0.0400 lbs.
#
# 	https://secure.coverart.bookstores.com/large/959/3-5959.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Need for Speed Most Wanted - Sony PSP  || Electronic Arts  || 0014633169195 || 19.99 || Everyone 10+ || Sony PSP
#                6/22/2010 || 4.1000 x 0.6000  || 0.1500 lbs.
#
# 	https://secure.coverart.bookstores.com/large/671/3-56671.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 NCAA Football 10 - Sony PSP  || Electronic Arts  || 0014633190144 || 19.99 || Everyone || Sony PSP
#                7/14/2009 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/013/3-6013.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Madden NFL 11 - Sony PSP  || Electronic Arts  || 0014633193534 || 19.99 || Everyone || Sony PSP
#                8/10/2010 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/068/3-6068.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Madden NFL 12 - Sony PSP  || Electronic Arts  || 0014633196702 || 19.99 || Everyone || Sony PSP
#                8/30/2011 || 4.1000 x 0.5000  || 0.3000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/499/3-58499.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Dead Or Alive Paradise  || TechnoMarine  || 0018946010670 || 29.99 || Mature || Sony PSP
#                3/15/2010 || 4.1000 x 0.6000  || 0.2000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/092/3-6092.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 LEGO Indiana Jones 2 The Adventure Continues (Sony PSP) (UK Import)  || Unknown  || 0023272008413 || 1.0 || Rating Pending || Sony PSP
#                1/17/2044 || 4.1000 x 0.6000  || 0.1400 lbs.
#
# 	https://secure.coverart.bookstores.com/large/290/3-81290.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                
jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Formula 1 2009 (PSP)  || Codemasters  || 5024866342147 || 1.0 || Unknown || Sony PSP
#                1/17/2044 || 4.2000 x 0.6000  || 0.3600 lbs.
#
# 	https://secure.coverart.bookstores.com/large/579/3-63579.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 The Warriors (PSP)  || Rockstar  || 5026555280853 || 29.99 || Adults Only || Sony PSP
#                2/23/2007 || 4.0900 x 0.5500  || 0.1000 lbs.
#
# 	https://secure.coverart.bookstores.com/large/368/3-128368.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 FIFA 13 (Sony PSP)  || Unknown  || 5030930109882 || 1.0 || Everyone || Sony PSP
#                1/17/2044 || Unknown  || 1 lbs.
#
# 	https://secure.coverart.bookstores.com/large/218/3-128218.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Lego Batman: The Videogame - Platinum Edition (PSP)  || Warner Bros. Interactive  || 5051892017220 || 14.99 || Unknown || Sony PSP
#                3/26/2010 || 4.1700 x 0.4700  || 1.8400 lbs.
#
# 	https://secure.coverart.bookstores.com/large/639/3-63639.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Metal Slug Anthology (PSP)  || Namco Bandai  || 5060050945008 || 19.99 || Unknown || Sony PSP
#                2/9/2007 || 4.1000 x 0.6000  || 0.0900 lbs.
#
# 	https://secure.coverart.bookstores.com/large/016/3-78016.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#                 Military History Commander: Europe at War (PSP) by Slitherine  || Slitherine  || 5060193300030 || 154.07 || Kids to Adults || Sony PSP
#                8/18/2042 || 4.0900 x 0.4700  || 0.1800 lbs.
#
# 	https://secure.coverart.bookstores.com/large/626/3-83626.jpg
# ------------------------------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 5
# --------
#
#
# No Data Available

# %%
response = requests.get(sony_psp_link)
browser.get(sony_psp_link)
i = 1
file_name = 'data/Sony(PSP).csv'
with open(file_name, mode='w', encoding='utf-8') as csv_file:
            fieldnames = ['Name', 'Studio'  , 'UPC', 'Price' , 'ESRB' ,
                         'Platform' , 'Released_on' , 'Dimensions' , 'Weight' ,'Cover_image']
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            writer.writeheader()
            response = requests.get(sony_psp_link)
            while True :
                try :
                    soup = BeautifulSoup(response.text, 'html.parser')
                except :
                    soup = BeautifulSoup(response, 'html.parser')
                items_tag = soup.find_all('div',{'class':'itemListingDiv'}) 
                print('Saving Page ' + str(i) )
                print('----------------')
                for item_tag in items_tag : 
                    item_name = item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).get_text()
                    try :
                        studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
                        if studio == '' :
                            studio = 'Unknown'
                    except : 
                        studio = 'Unknown'
                    upc = item_tag.find('span',{'class':'searchISBNSpan'}).get_text().strip().split('/')[1].strip()
                    try :
                        price = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1])
                    except :
                        price  = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1].split(')')[0])
                    item_link =  item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).find('a').get('href')
                    item_link = 'https://www.bookstores.com' + item_link    
                    response = requests.get(item_link)
                    soup_item = BeautifulSoup(response.text, 'html.parser')
                    item_img_link = soup_item.find('img', {'id':'mainContentRegion_imgProductImage'}).get('src')
                    try :
                        esrb = soup_item.find('span', {'id':'mainContentRegion_lblAuthorFormatESRB'}).get_text()
                    except :
                        esrb='Unknown'
                    platform = soup_item.find('span', {'id':'mainContentRegion_lblEditionRatingPlatform'}).get_text().split(':')[1].strip()
                    released_on = soup_item.find('span', {'id':'mainContentRegion_lblPagesActorsReleaseDate'}).get_text().split(':')[1].strip()    
                    try :
                        dimensions = soup_item.find('span', {'id':'mainContentRegion_lblDimensions'}).get_text().split(':')[1].strip()
                    except :
                        dimensions='Unknown'    
                    try :
                        weight = soup_item.find('span', {'id':'mainContentRegion_lblWeight'}).get_text().split(':')[1].strip()
                    except :
                        weight='Unknown'  
                    writer.writerow({'Name': item_name, 'Studio': studio , 'UPC': upc , 'Price' :price  
                                    , 'ESRB' : esrb , 'Platform' : platform , 'Released_on' : released_on
                                    , 'Dimensions' : dimensions , 'Weight' : weight , 'Cover_image' : item_img_link})                
                try :         
                    browser.find_element_by_id('mainContentRegion_leftContentRegion_btnNext').click()
                    response = browser.page_source
                    time.sleep(3)                               
                    print('\n')
                    print('\tTo Next Page\n\n')
                    i +=1
                except : 
                    print('No Data Available')
                    break
# Out:
# Saving Page 1
# ----------------
#
#
# 	To Next Page
#
#
# Saving Page 2
# ----------------
#
#
# 	To Next Page
#
#
# Saving Page 3
# ----------------
#
#
# 	To Next Page
#
#
# Saving Page 4
# ----------------
#
#
# 	To Next Page
#
#
# Saving Page 5
# ----------------
# No Data Available

# %%
df = pd.read_csv('data/Mac.csv')
df
# Out:
#                                                  Name             Studio  \
# 0                                       Portal 2 - PC              Valve
# 1                                     The Sims 3 - PC    Electronic Arts
# 2                                   Dragon Age 2 - PC    Electronic Arts
# 3                                              Diablo           Blizzard
# 4                           IGT Slots: Wolf Run - Mac  Masque Publishing
# 5                The Sims 2 Pets Expansion Pack - Mac        Aspyr Media
# 6                Call of Duty 4: Modern Warfare - Mac        Aspyr Media
# 7                         The Sims 2 Bon Voyage - Mac        Aspyr Media
# 8              Nancy Drew: Trail of the Twister - Mac    Her Interactive
# 9     Nancy Drew: Shadow at the Water's Edge - PC/Mac    Her Interactive
# 10                           Age Of Empires III - Mac          Microsoft
# 11   Age of Empires III: The War Chiefs Expansion ...          Destineer
#
#              UPC  Price          ESRB        Platform Released_on  \
# 0    14633098808  29.99  Everyone 10+        Mac OS X   4/19/2011
# 1    14633153903  19.99          Teen        Mac OS X    6/2/2009
# 2    14633194999  19.99        Mature        Mac OS X    3/8/2011
# 3    20626711883  39.99        Mature             Mac   1/17/2044
# 4    98252104225  19.99          Teen  Mac OS X Intel    9/1/2010
# 5   618870115009  34.99          Teen             Mac   11/1/2006
# 6   618870117607  39.99        Mature  Mac OS X Intel    5/8/2011
# 7   618870117805  34.99          Teen             Mac  12/10/2007
# 8   767861600779  19.99      Everyone  Mac OS X Intel   6/29/2010
# 9   767861600793  19.99  Everyone 10+  Mac OS X Intel  10/19/2010
# 10  828068103248  49.99          Teen  Mac OS X Intel  11/21/2006
# 11  828068103309  10.00          Teen             Mac   6/12/2007
#
#          Dimensions       Weight  \
# 0   5.3000 x 0.6000  0.1000 lbs.
# 1           Unknown  0.4267 lbs.
# 2           Unknown  0.2500 lbs.
# 3   4.9000 x 0.4000  0.2000 lbs.
# 4           Unknown  0.2500 lbs.
# 5   5.3000 x 1.1000  0.3000 lbs.
# 6   5.3000 x 0.6000  0.2000 lbs.
# 7           Unknown  0.3300 lbs.
# 8   5.4000 x 0.6000  0.2500 lbs.
# 9           Unknown  0.3000 lbs.
# 10  5.3500 x 1.4200  0.5300 lbs.
# 11  5.3000 x 0.9000  0.3500 lbs.
#
#                                           Cover_image
# 0   https://secure.coverart.bookstores.com/large/6...
# 1   https://secure.coverart.bookstores.com/large/6...
# 2   https://secure.coverart.bookstores.com/large/6...
# 3   https://secure.coverart.bookstores.com/large/4...
# 4   https://secure.coverart.bookstores.com/large/5...
# 5   https://secure.coverart.bookstores.com/large/7...
# 6   https://secure.coverart.bookstores.com/large/7...
# 7   https://secure.coverart.bookstores.com/large/5...
# 8   https://secure.coverart.bookstores.com/large/6...
# 9   https://secure.coverart.bookstores.com/large/6...
# 10  https://secure.coverart.bookstores.com/large/7...
# 11  https://secure.coverart.bookstores.com/large/5...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name


# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         53 non-null     object
#  1   Studio       53 non-null     object
#  2   UPC          53 non-null     int64
#  3   Price        53 non-null     float64
#  4   ESRB         53 non-null     object
#  5   Platform     53 non-null     object
#  6   Released_on  53 non-null     object
#  7   Dimensions   53 non-null     object
#  8   Weight       53 non-null     object
#  9   Cover_image  53 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.3+ KB

# %% [markdown]
# ## Step Three :
# 1. Scraping data all categories that one or many web page
# 2. Saving this data in csv file (Video Games.csv)

# %%
category_link_list.reverse()

# %%
category_name_list.reverse()

# %%
category_name_list
# Out:
# ['Mac',
#  'PC',
#  'Nintendo DS',
#  'Nintendo 3DS',
#  'Sony PSP',
#  'Wii',
#  'Xbox 360',
#  'PlayStation 3']

# %%
j = 0
file_name = 'data/Video Games.csv'
with open(file_name, mode='w', encoding='utf-8') as csv_file:
            fieldnames = ['Name', 'Studio'  , 'UPC', 'Price' ,'Category', 'ESRB' ,
                         'Platform' , 'Released_on' , 'Dimensions' ,  'Weight' ,'Cover_image']
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            writer.writeheader()
            for link in category_link_list : 
                i = 1
                response = requests.get(link)
                browser.get(link)
                print('Scraping ' +category_name_list[j] + ' Games')
                print('---------------------------------- \n\n')
                while True :
                    try :
                        soup = BeautifulSoup(response.text, 'html.parser')
                    except :
                        soup = BeautifulSoup(response, 'html.parser')
                    items_tag = soup.find_all('div',{'class':'itemListingDiv'}) 
                    print('\tSaving Page ' + str(i) )
                    print('\t----------------')
                    for item_tag in items_tag : 
                        item_name = item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).get_text()
                        try :
                            studio = item_tag.find('span', {'class':'searchAuthorSpan mobile Truncate'}).get_text().strip()
                            if studio == '' :
                                studio = 'Unknown'
                        except : 
                            studio = 'Unknown'
                        upc = item_tag.find('span',{'class':'searchISBNSpan'}).get_text().strip().split('/')[1].strip()
                        try :
                            price = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1])
                        except :
                            try :
                                price  = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1].replace(',',''))
                            except :
                                price  = float(item_tag.find('span',{'class':'listPriceAmount'}).get_text().strip().split('$')[1].split(')')[0])
                        item_link =  item_tag.find('span',{'class':'searchTitleSpan blue truncate'}).find('a').get('href')
                        item_link = 'https://www.bookstores.com' + item_link    
                        response = requests.get(item_link)
                        soup_item = BeautifulSoup(response.text, 'html.parser')
                        item_img_link = soup_item.find('img', {'id':'mainContentRegion_imgProductImage'}).get('src')
                        try :
                            esrb = soup_item.find('span', {'id':'mainContentRegion_lblAuthorFormatESRB'}).get_text()
                        except :
                            esrb='Unknown'
                        platform = soup_item.find('span', {'id':'mainContentRegion_lblEditionRatingPlatform'}).get_text().split(':')[1].strip()
                        released_on = soup_item.find('span', {'id':'mainContentRegion_lblPagesActorsReleaseDate'}).get_text().split(':')[1].strip()    
                        try :
                            dimensions = soup_item.find('span', {'id':'mainContentRegion_lblDimensions'}).get_text().split(':')[1].strip()
                        except :
                            dimensions='Unknown'    
                        try :
                            weight = soup_item.find('span', {'id':'mainContentRegion_lblWeight'}).get_text().split(':')[1].strip()
                        except :
                            weight='Unknown'  
                        writer.writerow({'Name': item_name, 'Studio': studio , 'UPC': upc ,  'Price' :price ,
                                       'Category':category_name_list[j], 'ESRB' : esrb , 'Platform' : platform , 'Released_on' : released_on
                                        , 'Dimensions' : dimensions , 'Weight' : weight , 'Cover_image' : item_img_link})
                    print()    
                    try :         
                        browser.find_element_by_id('mainContentRegion_leftContentRegion_btnNext').click()
                        response = browser.page_source
                        time.sleep(3)                               
                        print('\n')
                        print('\t\t>>To Next Page>>\n\n')
                        i+=1
                    except : 
                        print('\tNo Data Available')
                        print('\n')                        
                        print('\t\t>>To Category Page>>\n\n')
                        print('------'*20)
                        print('\n')
                        j+=1
                        break
# Out:
# Scraping Mac Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping PC Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 4
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 5
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 6
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 7
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 8
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping Nintendo DS Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 4
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 5
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 6
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 7
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 8
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 9
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 10
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 11
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 12
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 13
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 14
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping Nintendo 3DS Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping Sony PSP Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 4
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 5
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping Wii Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 4
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 5
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 6
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 7
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 8
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 9
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 10
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 11
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 12
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 13
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 14
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping Xbox 360 Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 4
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 5
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 6
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 7
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 8
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 9
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 10
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 11
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 12
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 13
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 14
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 15
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Scraping PlayStation 3 Games
# ----------------------------------
#
#
# 	Saving Page 1
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 2
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 3
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 4
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 5
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 6
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 7
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 8
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 9
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 10
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 11
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 12
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 13
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 14
# 	----------------
#
#
#
# 		>>To Next Page>>
#
#
# 	Saving Page 15
# 	----------------
#
# 	No Data Available
#
#
# 		>>To Category Page>>
#
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv(file_name)
df
# Out:
#                                                  Name             Studio  \
# 0                                       Portal 2 - PC              Valve
# 1                                     The Sims 3 - PC    Electronic Arts
# 2                                   Dragon Age 2 - PC    Electronic Arts
# 3                                              Diablo           Blizzard
# 4                           IGT Slots: Wolf Run - Mac  Masque Publishing
# ..                                                ...                ...
# 968                        Suikoden V - PlayStation 2             Konami
# 969          Metal Gear Solid 4: Guns of the Patriots             Konami
# 970          Metal Gear Solid 4: Guns of the Patriots             Konami
# 971           Silent Hill: Homecoming - Playstation 3             Konami
# 972   Silent Hill: Shattered Memories - PlayStation 2             Konami
#
#              UPC  Price       Category          ESRB        Platform  \
# 0    14633098808  29.99            Mac  Everyone 10+        Mac OS X
# 1    14633153903  19.99            Mac          Teen        Mac OS X
# 2    14633194999  19.99            Mac        Mature        Mac OS X
# 3    20626711883  39.99            Mac        Mature             Mac
# 4    98252104225  19.99            Mac          Teen  Mac OS X Intel
# ..           ...    ...            ...           ...             ...
# 968  83717201397  29.99  PlayStation 3          Teen    PlayStation2
# 969  83717201601  19.99  PlayStation 3        Mature   PlayStation 3
# 970  83717201748  19.99  PlayStation 3        Mature   PlayStation 3
# 971  83717201793  19.99  PlayStation 3        Mature   PlayStation 3
# 972  83717201861  19.99  PlayStation 3        Mature    PlayStation2
#
#     Released_on       Dimensions       Weight  \
# 0     4/19/2011  5.3000 x 0.6000  0.1000 lbs.
# 1      6/2/2009          Unknown  0.4267 lbs.
# 2      3/8/2011          Unknown  0.2500 lbs.
# 3     1/17/2044  4.9000 x 0.4000  0.2000 lbs.
# 4      9/1/2010          Unknown  0.2500 lbs.
# ..          ...              ...          ...
# 968    9/8/2006  5.1000 x 0.7000  0.0500 lbs.
# 969   6/12/2008  5.3000 x 0.6000  0.2000 lbs.
# 970   6/12/2008  5.3000 x 0.6000  0.2000 lbs.
# 971   9/30/2008  5.3000 x 0.6000  0.2000 lbs.
# 972   1/19/2010  5.3000 x 0.6000  0.3000 lbs.
#
#                                            Cover_image
# 0    https://secure.coverart.bookstores.com/large/6...
# 1    https://secure.coverart.bookstores.com/large/6...
# 2    https://secure.coverart.bookstores.com/large/6...
# 3    https://secure.coverart.bookstores.com/large/4...
# 4    https://secure.coverart.bookstores.com/large/5...
# ..                                                 ...
# 968  https://secure.coverart.bookstores.com/large/3...
# 969  https://secure.coverart.bookstores.com/large/6...
# 970  https://secure.coverart.bookstores.com/large/9...
# 971  https://secure.coverart.bookstores.com/large/1...
# 972  https://secure.coverart.bookstores.com/large/8...
#
# [973 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         973 non-null    object
#  1   Studio       973 non-null    object
#  2   UPC          973 non-null    int64
#  3   Price        973 non-null    float64
#  4   Category     973 non-null    object
#  5   ESRB         973 non-null    object
#  6   Platform     973 non-null    object
#  7   Released_on  973 non-null    object
#  8   Dimensions   973 non-null    object
#  9   Weight       973 non-null    object
#  10  Cover_image  973 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 83.7+ KB

# %%
df[df['Category'] == 'Mac']
# Out:
#                                                  Name             Studio  \
# 0                                       Portal 2 - PC              Valve
# 1                                     The Sims 3 - PC    Electronic Arts
# 2                                   Dragon Age 2 - PC    Electronic Arts
# 3                                              Diablo           Blizzard
# 4                           IGT Slots: Wolf Run - Mac  Masque Publishing
# 5                The Sims 2 Pets Expansion Pack - Mac        Aspyr Media
# 6                Call of Duty 4: Modern Warfare - Mac        Aspyr Media
# 7                         The Sims 2 Bon Voyage - Mac        Aspyr Media
# 8              Nancy Drew: Trail of the Twister - Mac    Her Interactive
# 9     Nancy Drew: Shadow at the Water's Edge - PC/Mac    Her Interactive
# 10                           Age Of Empires III - Mac          Microsoft
# 11   Age of Empires III: The War Chiefs Expansion ...          Destineer
#
#              UPC  Price Category          ESRB        Platform Released_on  \
# 0    14633098808  29.99      Mac  Everyone 10+        Mac OS X   4/19/2011
# 1    14633153903  19.99      Mac          Teen        Mac OS X    6/2/2009
# 2    14633194999  19.99      Mac        Mature        Mac OS X    3/8/2011
# 3    20626711883  39.99      Mac        Mature             Mac   1/17/2044
# 4    98252104225  19.99      Mac          Teen  Mac OS X Intel    9/1/2010
# 5   618870115009  34.99      Mac          Teen             Mac   11/1/2006
# 6   618870117607  39.99      Mac        Mature  Mac OS X Intel    5/8/2011
# 7   618870117805  34.99      Mac          Teen             Mac  12/10/2007
# 8   767861600779  19.99      Mac      Everyone  Mac OS X Intel   6/29/2010
# 9   767861600793  19.99      Mac  Everyone 10+  Mac OS X Intel  10/19/2010
# 10  828068103248  49.99      Mac          Teen  Mac OS X Intel  11/21/2006
# 11  828068103309  10.00      Mac          Teen             Mac   6/12/2007
#
#          Dimensions       Weight  \
# 0   5.3000 x 0.6000  0.1000 lbs.
# 1           Unknown  0.4267 lbs.
# 2           Unknown  0.2500 lbs.
# 3   4.9000 x 0.4000  0.2000 lbs.
# 4           Unknown  0.2500 lbs.
# 5   5.3000 x 1.1000  0.3000 lbs.
# 6   5.3000 x 0.6000  0.2000 lbs.
# 7           Unknown  0.3300 lbs.
# 777  https://secure.coverart.bookstores.com/large/9...
# 778  https://secure.coverart.bookstores.com/large/0...
# 779  https://secure.coverart.bookstores.com/large/0...
# ..                                                 ...
# 968  https://secure.coverart.bookstores.com/large/3...
# 969  https://secure.coverart.bookstores.com/large/6...
# 970  https://secure.coverart.bookstores.com/large/9...
# 971  https://secure.coverart.bookstores.com/large/1...
# 972  https://secure.coverart.bookstores.com/large/8...
#
# [198 rows x 11 columns]

# %%
df[df['Category'] == 'Wii']
# Out:
#                                                   Name                 Studio  \
# 384             The Legend of Zelda: Twilight Princess               Nintendo
# 385                        Donkey Kong Country Returns               Nintendo
# 386             The Legend of Zelda: Twilight Princess               Nintendo
# 387   The Legend of Zelda: Twilight Princess (Ninte...               Nintendo
# 388               Super Paper Mario (Nintendo Selects)               Nintendo
# ..                                                 ...                    ...
# 573   House Of The Dead: Overkill - Collector's Edi...                   Sega
# 574          uDraw Tablet including uDraw Studio (Wii)                    THQ
# 575   Ben 10 Alien Force: Vilgax Attacks - Nintendo...           D3 Publisher
# 576                                  Wii Sports Resort               Nintendo
# 577                            Call of Duty: Black Ops  Activision Publishing
#
#                UPC  Price Category                            ESRB  \
# 384    45496400453  19.99      Wii                            Teen
# 385    45496902001  29.99      Wii                        Everyone
# 386   605433010147  19.99      Wii                            Teen
# 387    45496902407  19.99      Wii                            Teen
# 388    45496902629  19.99      Wii                        Everyone
# ..             ...    ...      ...                             ...
# 573  5060138443488  39.99      Wii  Suitable for 18 years and over
# 574  4005209140881  51.05      Wii                          Exempt
# 575   879278340091   1.00      Wii                    Everyone 10+
# 576    45496901660  49.99      Wii                        Everyone
# 577    47875840058  49.99      Wii                          Mature
#
#          Platform Released_on       Dimensions       Weight  \
# 384  Nintendo Wii  11/17/2006  5.3000 x 0.6000  0.3900 lbs.
# 385  Nintendo Wii  11/21/2010          Unknown  0.5400 lbs.
# 386  Nintendo Wii  11/17/2006  5.3000 x 0.6000  0.1400 lbs.
# 387  Nintendo Wii   5/15/2011  5.3000 x 0.6000  0.4500 lbs.
# 388  Nintendo Wii   8/28/2011  5.3000 x 0.6000  0.4700 lbs.
# ..            ...         ...              ...          ...
# 573  Nintendo Wii   2/13/2009  5.5000 x 0.9000  0.3400 lbs.
# 574  Nintendo Wii    3/4/2011  7.7200 x 2.6000       1 lbs.
# 575  Nintendo Wii  10/27/2009  5.3000 x 0.7000  0.1000 lbs.
# 576  Nintendo Wii   7/26/2009  6.3000 x 0.9000  0.4500 lbs.
# 577  Nintendo Wii   11/9/2010          Unknown  0.3700 lbs.
#
#                                            Cover_image
# 384  https://secure.coverart.bookstores.com/large/3...
# 385  https://secure.coverart.bookstores.com/large/8...
# 386  https://secure.coverart.bookstores.com/large/4...
# 387  https://secure.coverart.bookstores.com/large/0...
# 388  https://secure.coverart.bookstores.com/large/4...
# ..                                                 ...
# 573  https://secure.coverart.bookstores.com/large/6...
# 574  https://secure.coverart.bookstores.com/large/2...
# 575  https://secure.coverart.bookstores.com/large/7...
# 576  https://secure.coverart.bookstores.com/large/0...
# 577  https://secure.coverart.bookstores.com/large/1...
#
# [194 rows x 11 columns]
